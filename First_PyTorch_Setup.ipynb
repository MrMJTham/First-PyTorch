# %% [markdown]
# <a href="https://colab.research.google.com/github/MrMJTham/First-PyTorch/blob/main/First_PyTorch_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# First PyTorch. run the PyTorch Framework in Google Colab.

# %%
import torch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print(torch.__version__)

# %% [markdown]
# What is Tensor?
# PyTorch tensors are created using "torch.tensor(x)" = https://pytorch.org/docs/stable/tensors.html
#
#
# Tensor is a data type

# %%
# Scalar
scalar = torch.tensor(7)

# %%
scalar.ndim
# Out:
# 0

# %%
scalar.shape
# Out:
# torch.Size([])

# %%
#Get tensor back as Python int
scalar.item()

# %%
#vector
vector = torch.tensor([7, 7])
vector
# Out:
# tensor([7, 7])

# %%
vector.ndim
# Out:
# 1

# %%
vector.shape
# Out:
# torch.Size([2])

# %%
#Matrix

matrix = torch.tensor([[7, 7],
                       [3,3]
                       ])
matrix
# Out:
# tensor([[7, 7],
#         [3, 3]])

# %%
matrix.ndim
# Out:
# 2

# %%
matrix.shape
# Out:
# torch.Size([2, 2])

# %%
matrix[1]
# Out:
# tensor([3, 3])

# %%
#tensor
#most of the time Pytorch will craft these
tensor = torch.tensor([[[1, 2, 3],
                        [3, 6, 9],
                        [2, 4, 6]
                        ]])
tensor
# Out:
# tensor([[[1, 2, 3],
#          [3, 6, 9],
#          [2, 4, 6]]])

# %%
tensor.ndim
# Out:
# 3

# %%
tensor.shape
# Out:
# torch.Size([1, 3, 3])

# %% [markdown]
# It means we got 1 3x3 shape. Explanation as follows
# ![tensor dimension.JPG](data:image/jpeg;base64,...)

# %%
mytensor = torch.tensor([[[2,1],
                          [1,2],
                           [3,4],
                           [5,6],
                           [5,6]
]])
mytensor
# Out:
# tensor([[[2, 1],
#          [1, 2],
#          [3, 4],
#          [5, 6],
#          [5, 6]]])

# %%
mytensor.ndim
# Out:
# 3

# %%
mytensor.shape
# Out:
# torch.Size([1, 5, 2])

# %%
mytensor[0,2,1]
# Out:
# tensor(4)

# %% [markdown]
# When calling tensor list in multiple dimension
#
# formula = (torch.Size - 1)
#
# ndim = calculate square brackets in curley bracket
